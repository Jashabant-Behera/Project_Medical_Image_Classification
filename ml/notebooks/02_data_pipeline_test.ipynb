# %%
# ── Cell 0: Fix working directory ──────────────────────────────────────────
import os, pathlib, sys

root = pathlib.Path(os.getcwd())
while not (root / 'requirements.txt').exists():
    root = root.parent
os.chdir(root)
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print(f'Working directory set to: {os.getcwd()}')
# Out:
# Working directory set to: d:\Jeet\projects\Data_Science\Project\Project_Medical_Image_Classification

# %% [markdown]
# # Cell 1 - Test Data Pipeline

# %%
from ml.training.dataloader import get_dataloaders

# data_dir uses project-root-relative path now that CWD is fixed
# num_workers=0 avoids multiprocessing issues in Windows notebooks
train_loader, val_loader, test_loader = get_dataloaders(
    data_dir='ml/data', batch_size=8, num_workers=0)

images, labels = next(iter(train_loader))
print('Image batch shape:', images.shape)   # Expected: torch.Size([8, 3, 224, 224])
print('Label batch:', labels)               # Expected: tensor of 0s and 1s
print('Train batches:', len(train_loader))
print('Val batches:  ', len(val_loader))
print('Test batches: ', len(test_loader))
# Out:
# d:\Jeet\projects\Data_Science\Project\Project_Medical_Image_Classification\venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Image batch shape: torch.Size([8, 3, 224, 224])
# Label batch: tensor([0, 1, 1, 0, 1, 1, 1, 1])
# Train batches: 652
# Val batches:   2
# Test batches:  78
